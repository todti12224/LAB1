# %% [markdown]
# # Preparation

# %%
import numpy as np  # for numerical operations and linear algebra
import pandas as pd  # for working with tables and CSV files

# %%
train = pd.read_csv(r'data/titanic/train.csv')
df = train.copy()

# %% [markdown]
# # The Basics

# %% [markdown]
# ## See the first 5 rows

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## last 5 rows

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## n_samples x n_features

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ## List of all the colums

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## Rows index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %% [markdown]
# ## Values with their counts in a particular column

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# ## General description of dataset.

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Creating DataFrame

# %% [markdown]
# ## empty data frame

# %%
df_empty=pd.DataFrame()
df_empty.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## From dict

# %%
student_dict = {'Name': ['A','B','C'], 'Age': [24,18,17], 'Roll': [1,2,3]}
df_student = pd.DataFrame(student_dict).reset_index(drop=True)  # create DataFrame and reset index to avoid an extra index column
df_student.head()  # display the first rows of the DataFrame
# Out:
#   Name  Age  Roll
# 0    A   24     1
# 1    B   18     2
# 2    C   17     3

# %% [markdown]
# # Treating null values

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## on whole df.

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## on a particular column

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(177)

# %% [markdown]
# ## Impute null values

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Sex'].fillna(df['Sex'].mode(),inplace=True)
df['Sex'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Modify/Add new column(s)

# %% [markdown]
# ## Adding another column or modify a column

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Sex']=df['Sex'].map({"male":'0',"female":"1"})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %% [markdown]
# ## Finding last name and first name from Name column.

# %%
df['last_name']=df['Name'].apply(lambda x: x.split(',')[0])
df['first_name']=df['Name'].apply(lambda x: ' '.join(x.split(',')[1:]))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name
# 0                              Mr. Owen Harris
# 1   Mrs. John Bradley (Florence Briggs Thayer)
# 2                                  Miss. Laina
# 3           Mrs. Jacques Heath (Lily May Peel)
# 4                            Mr. William Henry

# %% [markdown]
# ## Sets to 1 for men in 3rd class.

# %%
df['Third_Male'] = ((df['Pclass'] == 3) & (df['Sex'] == "0")).astype(int)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Third_Male
# 0                              Mr. Owen Harris           1
# 1   Mrs. John Bradley (Florence Briggs Thayer)           0
# 2                                  Miss. Laina           0
# 3           Mrs. Jacques Heath (Lily May Peel)           0
# 4                            Mr. William Henry           1

# %% [markdown]
# ## Calling some custom function

# %%
def find_age_group(value):
    if value < 18:
        return 1
    elif value < 40:
        return 2
    elif value < 60:
        return 3
    else:
        return 4

df['Age_group'] = df['Age'].apply(find_age_group)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Third_Male  Age_group
# 0                              Mr. Owen Harris           1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)           0          2
# 2                                  Miss. Laina           0          2
# 3           Mrs. Jacques Heath (Lily May Peel)           0          2
# 4                            Mr. William Henry           1          2

# %% [markdown]
# # Deleting columns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Third_Male  Age_group
# 0                              Mr. Owen Harris           1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)           0          2
# 2                                  Miss. Laina           0          2
# 3           Mrs. Jacques Heath (Lily May Peel)           0          2
# 4                            Mr. William Henry           1          2

# %%
df = df.drop(['PassengerId'], axis=1)
# drop the 'PassengerId' column; using inplace=True would modify df directly, here we create a new DataFrame
df.head()  # display the first rows after dropping the column
# Out:
#    Survived  Pclass                                               Name Sex  \
# 0         0       3                            Braund, Mr. Owen Harris   0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1
# 2         1       3                             Heikkinen, Miss. Laina   1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1
# 4         0       3                           Allen, Mr. William Henry   0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  last_name  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Third_Male  Age_group
# 0                              Mr. Owen Harris           1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)           0          2
# 2                                  Miss. Laina           0          2
# 3           Mrs. Jacques Heath (Lily May Peel)           0          2
# 4                            Mr. William Henry           1          2

# %% [markdown]
# # Renaming columns

# %%
df=df.rename(columns={'Sex':'Gender','Name':'Full Name','last_name':'Surname','first_name':'Name'})
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Third_Male  Age_group
# 0                              Mr. Owen Harris           1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)           0          2
# 2                                  Miss. Laina           0          2
# 3           Mrs. Jacques Heath (Lily May Peel)           0          2
# 4                            Mr. William Henry           1          2

# %% [markdown]
# # Slicing DataFrame

# %%
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Third_Male  Age_group
# 0                              Mr. Owen Harris           1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)           0          2
# 2                                  Miss. Laina           0          2
# 3           Mrs. Jacques Heath (Lily May Peel)           0          2
# 4                            Mr. William Henry           1          2

# %% [markdown]
# ## All rows with pclass==3

# %%
df_third_class = df[df['Pclass'] == 3].reset_index(drop=True)  # select third-class passengers and reset index to remove old indexing
df_third_class.head()  # display the first rows of the filtered DataFrame
# Out:
#    Survived  Pclass                       Full Name Gender        Age  SibSp  \
# 0         0       3         Braund, Mr. Owen Harris      0  22.000000      1
# 1         1       3          Heikkinen, Miss. Laina      1  26.000000      0
# 2         0       3        Allen, Mr. William Henry      0  35.000000      0
# 3         0       3                Moran, Mr. James      0  29.699118      0
# 4         0       3  Palsson, Master. Gosta Leonard      0   2.000000      3
#
#    Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 2      0            373450   8.0500   NaN        S      Allen
# 3      0            330877   8.4583   NaN        Q      Moran
# 4      1            349909  21.0750   NaN        S    Palsson
#
#                      Name  Third_Male  Age_group
# 0         Mr. Owen Harris           1          2
# 1             Miss. Laina           0          2
# 2       Mr. William Henry           1          2
# 3               Mr. James           1          2
# 4   Master. Gosta Leonard           1          1

# %% [markdown]
# ## Females with age > 60

# %%
df_aged=df[(df['Age']>60) & (df['Gender']=="1")]
df_aged.head()
# Out:
#      Survived  Pclass                                  Full Name Gender   Age  \
# 275         1       1          Andrews, Miss. Kornelia Theodosia      1  63.0
# 483         1       3                     Turkula, Mrs. (Hedwig)      1  63.0
# 829         1       1  Stone, Mrs. George Nelson (Martha Evelyn)      1  62.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked  Surname  \
# 275      1      0   13502  77.9583    D7        S  Andrews
# 483      0      0    4134   9.5875   NaN        S  Turkula
# 829      0      0  113572  80.0000   B28      NaN    Stone
#
#                                     Name  Third_Male  Age_group
# 275             Miss. Kornelia Theodosia           0          4
# 483                        Mrs. (Hedwig)           0          4
# 829   Mrs. George Nelson (Martha Evelyn)           0          4

# %% [markdown]
# ## Selecting some columns.

# %%
df1=df[['Age','Pclass','Gender']]
df1.head()
# Out:
#     Age  Pclass Gender
# 0  22.0       3      0
# 1  38.0       1      1
# 2  26.0       3      1
# 3  35.0       1      1
# 4  35.0       3      0

# %% [markdown]
# ## Select numerical columns only

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
df_num = df.select_dtypes(include=numerics)
df_num.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Third_Male  Age_group
# 0         0       3  22.0      1      0   7.2500           1          2
# 1         1       1  38.0      1      0  71.2833           0          2
# 2         1       3  26.0      0      0   7.9250           0          2
# 3         1       1  35.0      1      0  53.1000           0          2
# 4         0       3  35.0      0      0   8.0500           1          2

# %% [markdown]
# ## categorical columns

# %%
df_cat=df.select_dtypes(include=['object'])
df_cat.head()
# Out:
#                                            Full Name Gender            Ticket  \
# 0                            Braund, Mr. Owen Harris      0         A/5 21171
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1          PC 17599
# 2                             Heikkinen, Miss. Laina      1  STON/O2. 3101282
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1            113803
# 4                           Allen, Mr. William Henry      0            373450
#
#   Cabin Embarked    Surname                                         Name
# 0   NaN        S     Braund                              Mr. Owen Harris
# 1   C85        C    Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 2   NaN        S  Heikkinen                                  Miss. Laina
# 3  C123        S   Futrelle           Mrs. Jacques Heath (Lily May Peel)
# 4   NaN        S      Allen                            Mr. William Henry

# %% [markdown]
# # Slicing using iloc and loc

# %% [markdown]
# ## iloc

# %%
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Third_Male  Age_group
# 0                              Mr. Owen Harris           1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)           0          2
# 2                                  Miss. Laina           0          2
# 3           Mrs. Jacques Heath (Lily May Peel)           0          2
# 4                            Mr. William Henry           1          2

# %% [markdown]
# ### First 100 rows & all columns

# %%
df_sub1=df.iloc[0:100,:]
df_sub1.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Third_Male  Age_group
# 0                              Mr. Owen Harris           1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)           0          2
# 2                                  Miss. Laina           0          2
# 3           Mrs. Jacques Heath (Lily May Peel)           0          2
# 4                            Mr. William Henry           1          2

# %% [markdown]
# ### First 250 rows with a subset of columns

# %% [markdown]
# This will throw an error as iloc only consumes integres as indices.

# %%
col_idx = df.columns.get_loc('Age')  # get the numeric index of the 'Age' column (e.g., 4)
df_sub2 = df.iloc[:250, [col_idx]]  # select the first 250 rows of the 'Age' column using numeric indexing
df_sub2.head()  # display the first rows of the subset
# Out:
#     Age
# 0  22.0
# 1  38.0
# 2  26.0
# 3  35.0
# 4  35.0

# %%
# select the first 250 rows and specific columns by their numeric indices
df_sub2 = df.iloc[:250, [1, 8]]
df_sub2.head()  # display the first rows of the subset
# Out:
#    Pclass     Fare
# 0       3   7.2500
# 1       1  71.2833
# 2       3   7.9250
# 3       1  53.1000
# 4       3   8.0500

# %% [markdown]
# ## loc

# %%
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Third_Male  Age_group
# 0                              Mr. Owen Harris           1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)           0          2
# 2                                  Miss. Laina           0          2
# 3           Mrs. Jacques Heath (Lily May Peel)           0          2
# 4                            Mr. William Henry           1          2

# %% [markdown]
# ### First 500 rows.

# %%
df_sub3=df.loc[:500,:]

# %% [markdown]
# ### Gender and age of age >50

# %%
df_sub4=df.loc[(df['Age']>50),['Gender','Age']]
df_sub4.head()
# Out:
#    Gender   Age
# 6       0  54.0
# 11      1  58.0
# 15      1  55.0
# 33      0  66.0
# 54      0  65.0

# %% [markdown]
# # Adding a row

# %%
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Third_Male  Age_group
# 0                              Mr. Owen Harris           1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)           0          2
# 2                                  Miss. Laina           0          2
# 3           Mrs. Jacques Heath (Lily May Peel)           0          2
# 4                            Mr. William Henry           1          2

# %% [markdown]
# ## Adding row using 'append' or 'concat' functions

# %%
row = {'Age': 24, 'Full Name': 'Peter', 'Survived': 'Y'}
# convert the dictionary to a DataFrame and concatenate it with the existing df
df = pd.concat([df, pd.DataFrame([row])], ignore_index=True)
df.tail()  # display the last rows of the updated DataFrame
# Out:
#     Survived  Pclass                                 Full Name Gender  \
# 887        1     1.0              Graham, Miss. Margaret Edith      1
# 888        0     3.0  Johnston, Miss. Catherine Helen "Carrie"      1
# 889        1     1.0                     Behr, Mr. Karl Howell      0
# 890        0     3.0                       Dooley, Mr. Patrick      0
# 891        Y     NaN                                     Peter    NaN
#
#            Age  SibSp  Parch      Ticket   Fare Cabin Embarked   Surname  \
# 887  19.000000    0.0    0.0      112053  30.00   B42        S    Graham
# 888  29.699118    1.0    2.0  W./C. 6607  23.45   NaN        S  Johnston
# 889  26.000000    0.0    0.0      111369  30.00  C148        C      Behr
# 890  32.000000    0.0    0.0      370376   7.75   NaN        Q    Dooley
# 891  24.000000    NaN    NaN         NaN    NaN   NaN      NaN       NaN
#
#                                 Name  Third_Male  Age_group
# 887             Miss. Margaret Edith         0.0        2.0
# 888   Miss. Catherine Helen "Carrie"         0.0        2.0
# 889                  Mr. Karl Howell         0.0        2.0
# 890                      Mr. Patrick         1.0        2.0
# 891                              NaN         NaN        NaN

# %%
new_rows=pd.DataFrame([{'Age':24,'Full Name':'Peter','Survived':'Y'}])
df=pd.concat([df, new_rows],ignore_index=True)
df.tail()
# Out:
#     Survived  Pclass                                 Full Name Gender  \
# 888        0     3.0  Johnston, Miss. Catherine Helen "Carrie"      1
# 889        1     1.0                     Behr, Mr. Karl Howell      0
# 890        0     3.0                       Dooley, Mr. Patrick      0
# 891        Y     NaN                                     Peter    NaN
# 892        Y     NaN                                     Peter    NaN
#
#            Age  SibSp  Parch      Ticket   Fare Cabin Embarked   Surname  \
# 888  29.699118    1.0    2.0  W./C. 6607  23.45   NaN        S  Johnston
# 889  26.000000    0.0    0.0      111369  30.00  C148        C      Behr
# 890  32.000000    0.0    0.0      370376   7.75   NaN        Q    Dooley
# 891  24.000000    NaN    NaN         NaN    NaN   NaN      NaN       NaN
# 892  24.000000    NaN    NaN         NaN    NaN   NaN      NaN       NaN
#
#                                 Name  Third_Male  Age_group
# 888   Miss. Catherine Helen "Carrie"         0.0        2.0
# 889                  Mr. Karl Howell         0.0        2.0
# 890                      Mr. Patrick         1.0        2.0
# 891                              NaN         NaN        NaN
# 892                              NaN         NaN        NaN

# %% [markdown]
# ## Adding new row using loc

# %%
row=dict({'Age':24,'Full Name':'Peter','Survived':'Y'})
df.loc[len(df.index)]=row
df.tail()
# Out:
#     Survived  Pclass              Full Name Gender   Age  SibSp  Parch  \
# 889        1     1.0  Behr, Mr. Karl Howell      0  26.0    0.0    0.0
# 890        0     3.0    Dooley, Mr. Patrick      0  32.0    0.0    0.0
# 891        Y     NaN                  Peter    NaN  24.0    NaN    NaN
# 892        Y     NaN                  Peter    NaN  24.0    NaN    NaN
# 893        Y     NaN                  Peter    NaN  24.0    NaN    NaN
#
#      Ticket   Fare Cabin Embarked Surname              Name  Third_Male  \
# 889  111369  30.00  C148        C    Behr   Mr. Karl Howell         0.0
# 890  370376   7.75   NaN        Q  Dooley       Mr. Patrick         1.0
# 891     NaN    NaN   NaN      NaN     NaN               NaN         NaN
# 892     NaN    NaN   NaN      NaN     NaN               NaN         NaN
# 893     NaN    NaN   NaN      NaN     NaN               NaN         NaN
#
#      Age_group
# 889        2.0
# 890        2.0
# 891        NaN
# 892        NaN
# 893        NaN

# %% [markdown]
# # Dropping rows

# %%
df=df.drop(df.index[-1],axis=0) # Deletes last row
df.tail()
# Out:
#     Survived  Pclass                                 Full Name Gender  \
# 888        0     3.0  Johnston, Miss. Catherine Helen "Carrie"      1
# 889        1     1.0                     Behr, Mr. Karl Howell      0
# 890        0     3.0                       Dooley, Mr. Patrick      0
# 891        Y     NaN                                     Peter    NaN
# 892        Y     NaN                                     Peter    NaN
#
#            Age  SibSp  Parch      Ticket   Fare Cabin Embarked   Surname  \
# 888  29.699118    1.0    2.0  W./C. 6607  23.45   NaN        S  Johnston
# 889  26.000000    0.0    0.0      111369  30.00  C148        C      Behr
# 890  32.000000    0.0    0.0      370376   7.75   NaN        Q    Dooley
# 891  24.000000    NaN    NaN         NaN    NaN   NaN      NaN       NaN
# 892  24.000000    NaN    NaN         NaN    NaN   NaN      NaN       NaN
#
#                                 Name  Third_Male  Age_group
# 888   Miss. Catherine Helen "Carrie"         0.0        2.0
# 889                  Mr. Karl Howell         0.0        2.0
# 890                      Mr. Patrick         1.0        2.0
# 891                              NaN         NaN        NaN
# 892                              NaN         NaN        NaN

# %% [markdown]
# # Sorting

# %% [markdown]
# ## sorting by age say in decreasing order.

# %%
df=df.sort_values(by=['Age'],ascending=False) # can specify multiple columns in a list as well.
df.head()
# Out:
#     Survived  Pclass                             Full Name Gender   Age  \
# 630        1     1.0  Barkworth, Mr. Algernon Henry Wilson      0  80.0
# 851        0     3.0                   Svensson, Mr. Johan      0  74.0
# 96         0     1.0             Goldschmidt, Mr. George B      0  71.0
# 493        0     1.0               Artagaveytia, Mr. Ramon      0  71.0
# 116        0     3.0                  Connors, Mr. Patrick      0  70.5
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked       Surname  \
# 630    0.0    0.0     27042  30.0000   A23        S     Barkworth
# 851    0.0    0.0    347060   7.7750   NaN        S      Svensson
# 96     0.0    0.0  PC 17754  34.6542    A5        C   Goldschmidt
# 493    0.0    0.0  PC 17609  49.5042   NaN        C  Artagaveytia
# 116    0.0    0.0    370369   7.7500   NaN        Q       Connors
#
#                            Name  Third_Male  Age_group
# 630   Mr. Algernon Henry Wilson         0.0        4.0
# 851                   Mr. Johan         1.0        4.0
# 96                 Mr. George B         0.0        4.0
# 493                   Mr. Ramon         0.0        4.0
# 116                 Mr. Patrick         1.0        4.0

# %% [markdown]
# # Joins

# %%
sno=[i+1 for i in range(100)]
marks=np.random.randint(100,size=100)
print(len(marks))
marks_df=pd.DataFrame({'Sno':sno,'Marks':marks})
marks_df.head()
# Out:
# 100
#    Sno  Marks
# 0    1     51
# 1    2      6
# 2    3     25
# 3    4     91
# 4    5     14

# %%
sno=[i+1 for i in range(100)]
age=np.random.randint(100,size=100)
print(len(marks))
age_df=pd.DataFrame({'Sno':sno,'Age':age})
age_df.head()
# Out:
# 100
#    Sno  Age
# 0    1   31
# 1    2   97
# 2    3   49
# 3    4   11
# 4    5   88

# %% [markdown]
# ## Cross join

# %%
cross_join=pd.merge(marks_df,age_df,how='cross')
print(cross_join.shape)
cross_join.head()
# Out:
# (10000, 4)
#    Sno_x  Marks  Sno_y  Age
# 0      1     51      1   31
# 1      1     51      2   97
# 2      1     51      3   49
# 3      1     51      4   11
# 4      1     51      5   88

# %% [markdown]
# ## Inner join

# %%
inner_join = pd.merge(age_df, marks_df, how='inner', on='Sno')  # perform an inner join on 'Sno'; 'how' defaults to 'inner'
print(inner_join.shape)  # display the shape of the resulting DataFrame
inner_join.head()  # show the first rows of the merged DataFrame
# Out:
# (100, 3)
#    Sno  Age  Marks
# 0    1   31     51
# 1    2   97      6
# 2    3   49     25
# 3    4   11     91
# 4    5   88     14

# %% [markdown]
# ## Left and Right Outer Join(s)
#
# Lets add some more rows to either frame so that left and right outer join makes sense

# %%
age_df.loc[len(age_df.index)]={'Sno':101,'Age':23}
age_df.loc[len(age_df.index)]={'Sno':102,'Age':27}
age_df.loc[len(age_df.index)]={'Sno':104,'Age':29}
age_df.loc[len(age_df.index)]={'Sno':103,'Age':32}
age_df.loc[len(age_df.index)]={'Sno':105,'Age':53}

# %%
# left
left_join=pd.merge(age_df,marks_df,how='left',on='Sno')
print(left_join.shape)
left_join.tail()
# Out:
# (105, 3)
#      Sno  Age  Marks
# 100  101   23    NaN
# 101  102   27    NaN
# 102  104   29    NaN
# 103  103   32    NaN
# 104  105   53    NaN

# %%
#right join
right_join=pd.merge(marks_df,age_df,how='right',on='Sno')
print(right_join.shape)
right_join.tail()
# Out:
# (105, 3)
#      Sno  Marks  Age
# 100  101    NaN   23
# 101  102    NaN   27
# 102  104    NaN   29
# 103  103    NaN   32
# 104  105    NaN   53

# %% [markdown]
# ## Full outer join

# %%
marks_df.loc[len(marks_df.index)]={'Sno':106,'Marks':79}
marks_df.tail()
# Out:
#      Sno  Marks
# 96    97     30
# 97    98     10
# 98    99     78
# 99   100     76
# 100  106     79

# %%
#outer join
out_join=pd.merge(marks_df,age_df,how='outer',on='Sno')
print(out_join.shape)
out_join.tail(10)
# Out:
# (106, 3)
#      Sno  Marks   Age
# 96    97   30.0  67.0
# 97    98   10.0  20.0
# 98    99   78.0  86.0
# 99   100   76.0  89.0
# 100  101    NaN  23.0
# 101  102    NaN  27.0
# 102  103    NaN  32.0
# 103  104    NaN  29.0
# 104  105    NaN  53.0
# 105  106   79.0   NaN

# %% [markdown]
# # Groupby

# %%
df.head()
# Out:
#     Survived  Pclass                             Full Name Gender   Age  \
# 630        1     1.0  Barkworth, Mr. Algernon Henry Wilson      0  80.0
# 851        0     3.0                   Svensson, Mr. Johan      0  74.0
# 96         0     1.0             Goldschmidt, Mr. George B      0  71.0
# 493        0     1.0               Artagaveytia, Mr. Ramon      0  71.0
# 116        0     3.0                  Connors, Mr. Patrick      0  70.5
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked       Surname  \
# 630    0.0    0.0     27042  30.0000   A23        S     Barkworth
# 851    0.0    0.0    347060   7.7750   NaN        S      Svensson
# 96     0.0    0.0  PC 17754  34.6542    A5        C   Goldschmidt
# 493    0.0    0.0  PC 17609  49.5042   NaN        C  Artagaveytia
# 116    0.0    0.0    370369   7.7500   NaN        Q       Connors
#
#                            Name  Third_Male  Age_group
# 630   Mr. Algernon Henry Wilson         0.0        4.0
# 851                   Mr. Johan         1.0        4.0
# 96                 Mr. George B         0.0        4.0
# 493                   Mr. Ramon         0.0        4.0
# 116                 Mr. Patrick         1.0        4.0

# %%
groups=df.groupby(['Pclass'])
groups.get_group((1,))
# Out:
#     Survived  Pclass                             Full Name Gender    Age  \
# 630        1     1.0  Barkworth, Mr. Algernon Henry Wilson      0  80.00
# 96         0     1.0             Goldschmidt, Mr. George B      0  71.00
# 493        0     1.0               Artagaveytia, Mr. Ramon      0  71.00
# 745        0     1.0          Crosby, Capt. Edward Gifford      0  70.00
# 456        0     1.0             Millet, Mr. Francis Davis      0  65.00
# ..       ...     ...                                   ...    ...    ...
# 435        1     1.0             Carter, Miss. Lucile Polk      1  14.00
# 802        1     1.0   Carter, Master. William Thornton II      0  11.00
# 445        1     1.0             Dodge, Master. Washington      0   4.00
# 297        0     1.0          Allison, Miss. Helen Loraine      1   2.00
# 305        1     1.0        Allison, Master. Hudson Trevor      0   0.92
#
#      SibSp  Parch     Ticket      Fare    Cabin Embarked       Surname  \
# 630    0.0    0.0      27042   30.0000      A23        S     Barkworth
# 96     0.0    0.0   PC 17754   34.6542       A5        C   Goldschmidt
# 493    0.0    0.0   PC 17609   49.5042      NaN        C  Artagaveytia
# 745    1.0    1.0  WE/P 5735   71.0000      B22        S        Crosby
# 456    0.0    0.0      13509   26.5500      E38        S        Millet
# ..     ...    ...        ...       ...      ...      ...           ...
# 435    1.0    2.0     113760  120.0000  B96 B98        S        Carter
# 802    1.0    2.0     113760  120.0000  B96 B98        S        Carter
# 445    0.0    2.0      33638   81.8583      A34        S         Dodge
# 297    1.0    2.0     113781  151.5500  C22 C26        S       Allison
# 305    1.0    2.0     113781  151.5500  C22 C26        S       Allison
#
#                              Name  Third_Male  Age_group
# 630     Mr. Algernon Henry Wilson         0.0        4.0
# 96                   Mr. George B         0.0        4.0
# 493                     Mr. Ramon         0.0        4.0
# 745          Capt. Edward Gifford         0.0        4.0
# 456             Mr. Francis Davis         0.0        4.0
# ..                            ...         ...        ...
# 435             Miss. Lucile Polk         0.0        1.0
# 802   Master. William Thornton II         0.0        1.0
# 445            Master. Washington         0.0        1.0
# 297           Miss. Helen Loraine         0.0        1.0
# 305         Master. Hudson Trevor         0.0        1.0
#
# [216 rows x 15 columns]

# %% [markdown]
# ## Average Age per Pclass

# %%
df_grp1=df.groupby(['Pclass'])
df_grp1['Age'].mean()
# Out:
# Pclass
# 1.0    37.048118
# 2.0    29.866958
# 3.0    26.403259
# Name: Age, dtype: float64

# %% [markdown]
# ## Min/Max age per Pclass

# %%
df_grp1['Age'].min()
# Out:
# Pclass
# 1.0    0.92
# 2.0    0.67
# 3.0    0.42
# Name: Age, dtype: float64

# %%
df_grp1['Age'].max()
# Out:
# Pclass
# 1.0    80.0
# 2.0    70.0
# 3.0    74.0
# Name: Age, dtype: float64

# %% [markdown]
# ## Count

# %%
df_grp1['Age'].count()
# Out:
# Pclass
# 1.0    216
# 2.0    184
# 3.0    491
# Name: Age, dtype: int64

# %% [markdown]
# ## Using agg() function

# %%
df=train.copy()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Average per Pclass using 'agg' this time

# %%
df_grp2=df.groupby(['Pclass']).agg({'Age':lambda x: np.mean(x)}) 
df_grp2.head()
# Out:
#               Age
# Pclass
# 1       38.233441
# 2       29.877630
# 3       25.140620

# %% [markdown]
# ## Min/Max,count,Sum for each Pclass usign agg function

# %%
df_grp3=df.groupby(['Pclass']).agg({'Age':'min'}).rename(columns={'Age':'Min Age'})
# Use 'max'/'sum' etc. for that operation. Note that this ignores 'nan' values.
df_grp3.head()
# Out:
#         Min Age
# Pclass
# 1          0.92
# 2          0.67
# 3          0.42

# %% [markdown]
# ## Names of all the pasengers in that class.

# %%
df_grp4=df.groupby(['Pclass']).agg({'Name':lambda x:', '.join(x)})
df_grp4.head()
# Out:
#                                                      Name
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       Nasser, Mrs. Nicholas (Adele Achem), Hewlett, ...
# 3       Braund, Mr. Owen Harris, Heikkinen, Miss. Lain...

# %% [markdown]
# ## Note one thing that we can use multile agg functions on a single attribute by providing list in value part.

# %%
df_grp5=df.groupby(['Pclass']).agg({'Age':['max','min']})
df_grp5.head() # Creates a MultiOndex Dataframe
# Out:
#          Age
#          max   min
# Pclass
# 1       80.0  0.92
# 2       70.0  0.67
# 3       74.0  0.42

# %% [markdown]
# # Bonus: Iterating over rows in dataframe

# %%
for index,row in df.head().iterrows():
    print(row)
    pass
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# Name: 2, dtype: object
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                    35.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object
# PassengerId                           5
# Survived                              0
# Pclass                                3
# Name           Allen, Mr. William Henry
# Sex                                male
# Age                                35.0
# SibSp                                 0
# Parch                                 0
# Ticket                           373450
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Name: 4, dtype: object
